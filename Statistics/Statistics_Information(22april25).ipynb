# %% [markdown]
# # STATISTICS
#
# # DATA:
# Data is unorganised and raw data .
# Data is independent of Information.
# eg: readings of temperature in the suppose DataScience Lab from 7am then 7:10 then 7:20...etc
#
# # Information:
# Information is organised which is made up of data to draw insightful context,meaning data.
# Information is dependent on Data.
# eg:Drawing insights from this data is the information.
#
# # Why Statistical Analysis is Important?
#
# # Types of Data:
# 1.Quantitative - Discrete,Continuous
# 2.Qualitative-Nomial(colors:red,green;gender:Male,Female)
# ,Ordinal Data(having hirarchy eg:good ,better,best)
# # Types of Statistical Analysis Types:
# ### 1.Decriptive Statistics -Helps us to generate summary of data.
# mean ,median mode,Standard Deviation ,Variance.
#
# finding measure of central tendency(mean,median,mode),kurtosis,skewness
#
# ### 2.Inferential Statistics:Helps us to make inferences and predictions about a population basied on a sample.
# Population,Sample.
#
# ## NOTE:
# if outilers are present to replace the missing values we will use median imputation .
#
# if outliers are not there then for missing values we will use Mean Imputation.
#
# if your data is categorical then to fill the missing values we will use Mode Imputation.

# %% [markdown]
# # Mean: it is the representative of the data
# Summatioon of all values upto number of total number of values.
# ![image.png](attachment:ade82913-48d1-4792-a708-f2dd202ef26d.png)
#
# # Median :it is the representative of the data
# the middle number of all the numbers in spepcific column is called Median.

# %%
#here mean we will get as 1.67 million around 
#so we will go  for median which gives us 7000.

# %% [markdown]
# # 1.Finding Mean,Median ,Mode is called first Moment Business Decision
# # 2.FInding Variance,Standard Deviation is called Second Moment Business Decision
# # 3.Finding Skewness is called Third Moment Business Decision
# # 4.FInding Kurtosis(finding the peakedness ie the peak values of the graph) is called Forth Moment Business Decision

# %% [markdown]
# # mean<median:
# Data is right skewed
#
# # mean<median:
# Data is Left Skewed

# %% [markdown]
# # Variability
# How the data is being dispersed
#
# History test
# Name        Score
# Mohan        75
# Andreau      72
# Sofia        68
# Joe          65
# VIrat        67
# Abdul        73
#
# Average =70  =>Here variability is low .so its find to calculate it with mean
#
#
# Maths Test
# Name  Score
# M      91
# A       96
# S      43
# J      47
# V     51
# A      90
#
# Average =70  =>Here variabiability is very high.when this there we will calculate the Mean Absolute Value.
#
#
# #We need a metric which show the spread
#
# # variabiability is very high.when this there we will calculate the Mean Absolute Value.

# %% [markdown]
# #### HistoryTest1
# Name Abs(Score-Avg)
# M  5
#
# Ab 2
#
# S  2
#
# J  2
#
# V  5
#
# A  3
#
# B  3
#
# MAD=3.33
#
# #### Historytest2
#
#
# Name Abs(Score-Avg)
# M  23
#
# Ab 0
#
# S  0
#
# J  0
#
# V  7
#
# A  0
#
# B  0
#
# MAD=3.33

# %%
#now let us consider we have taken 2 test of history,where MAD value is 3.333 for both
#but if we observe the distribution ,most of the points are located at mean. 
#but there is one data pt. which far away from the mean 
#on LHS datapts. are distributed between 65 to 75 but on RHS it is 63 to 83.
#here data distribution is widely spread
